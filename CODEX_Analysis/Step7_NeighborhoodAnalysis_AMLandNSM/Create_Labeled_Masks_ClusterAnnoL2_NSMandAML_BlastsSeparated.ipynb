# %%
# This script takes the cluster csvs generated by Export_Cluster_CSVs.R and exports labeled masks for each image from the NBM atlas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tifffile

# %%
sample_names =  ["SB67_NBM44_AML2_191_CODEX_Mesmer","SB67_NBM46_AML1_382_CODEX_Mesmer","SB67_NBM47_NSM3_1996_CODEX_Mesmer",
"SB67_NBM48_NSM1_1720_CODEX_Mesmer","SB67_NBM49_NSM2_1086_CODEX_Mesmer","SB67_NBM51_AML1_183_CODEX_Mesmer",
"SB67_NBM52_AML3_1329_CODEX_Mesmer","SB67_NBM54_AML3_1443_CODEX_Mesmer"]

# %%
for name in sample_names:
	print(name)
	clusters = '/mnt/isilon/tan_lab_imaging/Analysis/bandyopads/NBM_CODEX_Atlas_NeighborhoodMasks/Masks_ForManuscript/AMLandNSM_ClusterMask_CSVs/Unfiltered_'+name+'_classified_cluster_anno_l2_separate_blasts_separated_10252023.csv' 
	mask = '/mnt/isilon/tan_lab_imaging/Analysis/bandyopads/NBM_CODEX_Atlas_NeighborhoodMasks/Masks_ForManuscript/SegmentationMasks/AMLandNSM/'+name+'_Scan1_segmentation_cell.tif'
	output = '/mnt/isilon/tan_lab_imaging/Analysis/bandyopads/NBM_CODEX_Atlas_NeighborhoodMasks/Masks_ForManuscript/LabeledAMLandNSM_Masks/Unfiltered_'+name+'_BlastsSeparated_LabeledMask.tiff'
	print('Reading Clusters')
	clusters = pd.read_csv(clusters)
	print('Reading Mask')
	mask = tifffile.imread(mask)

	# Initialize numpy array from segmentation mask
	print('Initializing numpy array')
	masks_out = mask.copy()
	masks_out = np.array(masks_out).astype(int)
	print(masks_out.dtype)

	#Convert those cells that have been filtered out to zero
	print('Filtering cells')
	filter_mask = np.isin(masks_out,clusters['CellID'], invert=True)
	masks_out[filter_mask] = 0

	# Create dictionary mapping Cell ID keys to cluster values
	print('Creating mapping')
	mapping = dict(zip(clusters["CellID"], clusters["Annotation"]))

	# Define function to change the values in input array by key-value pairs from dict
	def mp(entry):
	    return mapping[entry] if entry in mapping.keys() else entry

	print('Vectorizing array')
	mp = np.vectorize(mp)

	print('Converting Values') 
	out = mp(masks_out)

	print('Saving mask')
	tifffile.imwrite(output, out)
# Out:
# SB67_NBM44_AML2_191_CODEX_Mesmer
# Reading Clusters
# Reading Mask
# Initializing numpy array
# int64
# Filtering cells
# Creating mapping
# Vectorizing array
# Converting Values
# Saving mask
# SB67_NBM46_AML1_382_CODEX_Mesmer
# Reading Clusters
# Reading Mask
# Initializing numpy array
# int64
# Filtering cells
# Creating mapping
# Vectorizing array
# Converting Values
# Saving mask
# SB67_NBM47_NSM3_1996_CODEX_Mesmer
# Reading Clusters
# Reading Mask
# Initializing numpy array
# int64
# Filtering cells
# Creating mapping
# Vectorizing array
# Converting Values
# Saving mask
# SB67_NBM48_NSM1_1720_CODEX_Mesmer
# Reading Clusters
# Reading Mask
# Initializing numpy array
# int64
# Filtering cells
# Creating mapping
# Vectorizing array
# Converting Values
# Saving mask
# SB67_NBM49_NSM2_1086_CODEX_Mesmer
# Reading Clusters
# Reading Mask
# Initializing numpy array
# int64
# Filtering cells
# Creating mapping
# Vectorizing array
# Converting Values
# Saving mask
# ...
